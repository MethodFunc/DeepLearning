# %%
import cv2, os, random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from glob import glob
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split

# %%
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path = 'dataset/dogs-vs-cats/train'

# %%
ROW, COL = 96, 96

dogs, cats = [], []
test_dogs, test_cats= [], []

# %%
dog_path = os.path.join(path, 'dog*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)
    
print('Dogs Image loaded')
# Out:
# Dogs Image loaded

# %%
cat_path = os.path.join(path, 'cat*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)
    
print('Dogs Image loaded')
# Out:
# Dogs Image loaded

# %%
def show_img(labels):
    plt.figure(figsize=(12, 8))
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(labels))
        plt.imshow(img, cmap=plt.get_cmap('gray'))
        plt.axis('off')
    plt.show()

# %%
show_img(dogs)

# %%
show_img(cats)

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
x_data = np.concatenate((dogs, cats), axis = 0)
y_data = np.concatenate((y_dogs, y_cats), axis = 0)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=seed, shuffle=True)

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1),  activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 18,940,385
# Trainable params: 18,940,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = keras.losses.binary_crossentropy,
             optimizer = keras.optimizers.Nadam(),
             metrics = ['accuracy'])

# %%
modelpath = "../model/dogsvscats-binary-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = keras.callbacks.ModelCheckpoint(modelpath,verbose=1, save_best_only=True)

# %%
history = model.fit(x_train, y_train, validation_split=0.2, epochs=10, batch_size=32, callbacks=[checkpointer])
# Out:
# Train on 16000 samples, validate on 4000 samples
# Epoch 1/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.6696 - accuracy: 0.6031
# Epoch 00001: val_loss improved from inf to 0.60331, saving model to ../model/dogsvscats-binary-01-0.6033.hdf5
# 16000/16000 [==============================] - 305s 19ms/sample - loss: 0.6698 - accuracy: 0.6031 - val_loss: 0.6033 - val_accuracy: 0.6837
# Epoch 2/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.5493 - accuracy: 0.7253
# Epoch 00002: val_loss improved from 0.60331 to 0.48919, saving model to ../model/dogsvscats-binary-02-0.4892.hdf5
# 16000/16000 [==============================] - 302s 19ms/sample - loss: 0.5491 - accuracy: 0.7254 - val_loss: 0.4892 - val_accuracy: 0.7663
# Epoch 3/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.4609 - accuracy: 0.7804
# Epoch 00003: val_loss improved from 0.48919 to 0.46366, saving model to ../model/dogsvscats-binary-03-0.4637.hdf5
# 16000/16000 [==============================] - 302s 19ms/sample - loss: 0.4609 - accuracy: 0.7804 - val_loss: 0.4637 - val_accuracy: 0.7780
# Epoch 4/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.3928 - accuracy: 0.8252
# Epoch 00004: val_loss improved from 0.46366 to 0.40629, saving model to ../model/dogsvscats-binary-04-0.4063.hdf5
# 16000/16000 [==============================] - 302s 19ms/sample - loss: 0.3926 - accuracy: 0.8253 - val_loss: 0.4063 - val_accuracy: 0.8142
# Epoch 5/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.3200 - accuracy: 0.8627
# Epoch 00005: val_loss did not improve from 0.40629
# 16000/16000 [==============================] - 302s 19ms/sample - loss: 0.3200 - accuracy: 0.8626 - val_loss: 0.4252 - val_accuracy: 0.8102
# Epoch 6/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.2479 - accuracy: 0.8957
# Epoch 00006: val_loss did not improve from 0.40629
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.2476 - accuracy: 0.8958 - val_loss: 0.4432 - val_accuracy: 0.8235
# Epoch 7/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.1852 - accuracy: 0.9265
# Epoch 00007: val_loss did not improve from 0.40629
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.1851 - accuracy: 0.9266 - val_loss: 0.4379 - val_accuracy: 0.8225
# Epoch 8/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.1403 - accuracy: 0.9468
# Epoch 00008: val_loss did not improve from 0.40629
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.1404 - accuracy: 0.9468 - val_loss: 0.4962 - val_accuracy: 0.8265
# Epoch 9/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.1025 - accuracy: 0.9602
# Epoch 00009: val_loss did not improve from 0.40629
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.1023 - accuracy: 0.9603 - val_loss: 0.5806 - val_accuracy: 0.8207
# Epoch 10/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.0858 - accuracy: 0.9680
# Epoch 00010: val_loss did not improve from 0.40629
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.0857 - accuracy: 0.9681 - val_loss: 0.6307 - val_accuracy: 0.8207

# %%
del model

# %%
model = keras.models.load_model('../model/dogsvscats-binary-04-0.4063.hdf5')

# %%
model.evaluate(x_test , y_test, verbose=0)
# Out:
# [0.4155305853843689, 0.8088]
