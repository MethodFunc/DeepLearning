# %%
import cv2, os, random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from glob import glob
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split

# %%
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path = 'dataset/dogs-vs-cats/train'

# %%
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)
print('All dog images loaded')
# Out:
# All dog images loaded

# %%
cat_path = os.path.join(path, 'cat.*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)
print('All cat images loaded')
# Out:
# All cat images loaded

# %%
def shows(label):
    plt.figure(figsize=(12, 8))
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(label))
        plt.imshow(img, cmap=plt.get_cmap('gray'))
        plt.axis('off')

    plt.show()

# %%
shows(dogs)

# %%
shows(cats)

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
dogs.shape, y_dogs.shape
# Out:
# ((12500, 96, 96, 1), (12500,))

# %%
x_data = np.concatenate((dogs, cats), axis = 0)
y_data = np.concatenate((y_dogs, y_cats), axis = 0)

# %%
y_data = tf.keras.utils.to_categorical(y_data, 2)

# %%
x_train, x_test, y_train, t_test = train_test_split(x_data, y_data, test_size=0.2, random_state = seed)

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1),  activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(2, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = keras.losses.categorical_crossentropy,
             optimizer = keras.optimizers.Nadam(),
             metrics = ['accuracy'])

# %%
modelpath = "../model/dogsvscats-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = keras.callbacks.ModelCheckpoint(modelpath,verbose=1, save_best_only=True)

# %%
history = model.fit(x_train, y_train, validation_split=0.2, epochs=10, batch_size=32, callbacks=[checkpointer])
# Out:
# Train on 16000 samples, validate on 4000 samples
# Epoch 1/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.6710 - accuracy: 0.6046
# Epoch 00001: val_loss improved from inf to 0.61016, saving model to ../model/dogsvscats-01-0.6102.hdf5
# 16000/16000 [==============================] - 304s 19ms/sample - loss: 0.6712 - accuracy: 0.6047 - val_loss: 0.6102 - val_accuracy: 0.6740
# Epoch 2/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.5577 - accuracy: 0.7195
# Epoch 00002: val_loss improved from 0.61016 to 0.47831, saving model to ../model/dogsvscats-02-0.4783.hdf5
# 16000/16000 [==============================] - 302s 19ms/sample - loss: 0.5577 - accuracy: 0.7194 - val_loss: 0.4783 - val_accuracy: 0.7715
# Epoch 3/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.4534 - accuracy: 0.7862
# Epoch 00003: val_loss improved from 0.47831 to 0.43731, saving model to ../model/dogsvscats-03-0.4373.hdf5
# 16000/16000 [==============================] - 302s 19ms/sample - loss: 0.4535 - accuracy: 0.7861 - val_loss: 0.4373 - val_accuracy: 0.8000
# Epoch 4/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.3898 - accuracy: 0.8225
# Epoch 00004: val_loss improved from 0.43731 to 0.39376, saving model to ../model/dogsvscats-04-0.3938.hdf5
# 16000/16000 [==============================] - 303s 19ms/sample - loss: 0.3895 - accuracy: 0.8227 - val_loss: 0.3938 - val_accuracy: 0.8133
# Epoch 5/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.3227 - accuracy: 0.8579
# Epoch 00005: val_loss improved from 0.39376 to 0.37728, saving model to ../model/dogsvscats-05-0.3773.hdf5
# 16000/16000 [==============================] - 302s 19ms/sample - loss: 0.3226 - accuracy: 0.8580 - val_loss: 0.3773 - val_accuracy: 0.8288
# Epoch 6/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.2479 - accuracy: 0.8954
# Epoch 00006: val_loss did not improve from 0.37728
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.2478 - accuracy: 0.8954 - val_loss: 0.4144 - val_accuracy: 0.8313
# Epoch 7/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.1883 - accuracy: 0.9252
# Epoch 00007: val_loss did not improve from 0.37728
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.1881 - accuracy: 0.9252 - val_loss: 0.4543 - val_accuracy: 0.8320
# Epoch 8/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9444
# Epoch 00008: val_loss did not improve from 0.37728
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.1421 - accuracy: 0.9445 - val_loss: 0.4778 - val_accuracy: 0.8292
# Epoch 9/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.1079 - accuracy: 0.9583
# Epoch 00009: val_loss did not improve from 0.37728
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.1080 - accuracy: 0.9582 - val_loss: 0.4719 - val_accuracy: 0.8235
# Epoch 10/10
# 15968/16000 [============================>.] - ETA: 0s - loss: 0.0896 - accuracy: 0.9679
# Epoch 00010: val_loss did not improve from 0.37728
# 16000/16000 [==============================] - 300s 19ms/sample - loss: 0.0896 - accuracy: 0.9679 - val_loss: 0.5897 - val_accuracy: 0.8282

# %%
del model

# %%
model = keras.models.load_model('../model/dogsvscats-05-0.3773.hdf5')

# %%
model.evaluate(x_test , t_test, verbose=0)
# Out:
# [0.39268309766054155, 0.8238]
