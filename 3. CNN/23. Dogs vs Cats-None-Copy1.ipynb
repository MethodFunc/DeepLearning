# %%
import cv2, os, random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from glob import glob
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split

# %%
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path = 'dataset/dogs-vs-cats/work/'

# %%
ROW, COL = 96, 96

dogs, cats = [], []
test_dogs, test_cats= [], []
test_dogl, test_catl = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'train/dog.*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)
print('All dog images loaded')
# Out:
# All dog images loaded

# %%
dog_path = os.path.join(path, 'test/dog.*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    test_dogs.append(dog)
print('All test dog images loaded')
# Out:
# All test dog images loaded

# %%
cat_path = os.path.join(path, 'train/cat.*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)
print('All cat images loaded')
# Out:
# All cat images loaded

# %%
cat_path = os.path.join(path, 'test/cat.*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    test_cats.append(cat)
print('All test cat images loaded')
# Out:
# All test cat images loaded

# %%
def shows(label):
    plt.figure(figsize=(12, 8))
    for i in range(5):
        plt.subplot(1, 5, i+1)
        img = image.array_to_img(random.choice(label))
        plt.imshow(img, cmap=plt.get_cmap('gray'))
        plt.axis('off')

    plt.show()

# %%
shows(dogs)

# %%
shows(cats)

# %%
shows(test_dogs)

# %%
shows(test_cats)

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]
test_dogl = [1 for item in enumerate(test_dogs)]
test_catl = [0 for item in enumerate(test_cats)]

# %%
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
dogs.shape, y_dogs.shape
# Out:
# ((10000, 96, 96, 1), (10000,))

# %%
x_train = np.concatenate((dogs, cats), axis = 0)
y_train = np.concatenate((y_dogs, y_cats), axis = 0)

# %%
x_train.shape, y_train.shape
# Out:
# ((20000, 96, 96, 1), (20000,))

# %%
test_dogs = np.asarray(test_dogs).astype('float32') / 255
test_cats = np.asarray(test_cats).astype('float32') / 255
test_dogl = np.asarray(test_dogl).astype('int32')
test_catl = np.asarray(test_catl).astype('int32')

# %%
x_test = np.concatenate((test_dogs, test_cats), axis = 0)
y_test = np.concatenate((test_dogl, test_catl), axis = 0)

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1),  activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.1),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.1),
    Conv2D(128, (3,3), padding='same', activation='relu'),
    Conv2D(128, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(256, activation='relu'),
    Dropout(.5),
    Dense(128, activation='relu'),
    Dropout(.5),
    Dense(64, activation='relu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9437696
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 9,896,673
# Trainable params: 9,896,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = keras.losses.binary_crossentropy,
             optimizer = keras.optimizers.Nadam(),
             metrics = ['accuracy'])

# %%
modelpath = "../model/dogsvscats-binary-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = keras.callbacks.ModelCheckpoint(modelpath,verbose=1, save_best_only=True)

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=32, callbacks=[checkpointer])
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6939 - accuracy: 0.5025
# Epoch 00001: val_loss improved from inf to 0.69325, saving model to ../model/dogsvscats-binary-01-0.6933.hdf5
# 20000/20000 [==============================] - 731s 37ms/sample - loss: 0.6939 - accuracy: 0.5024 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 2/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6936 - accuracy: 0.4936
# Epoch 00002: val_loss improved from 0.69325 to 0.69315, saving model to ../model/dogsvscats-binary-02-0.6932.hdf5
# 20000/20000 [==============================] - 719s 36ms/sample - loss: 0.6936 - accuracy: 0.4936 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6934 - accuracy: 0.4983
# Epoch 00003: val_loss did not improve from 0.69315
# 20000/20000 [==============================] - 717s 36ms/sample - loss: 0.6934 - accuracy: 0.4983 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 4/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6932 - accuracy: 0.5016
# Epoch 00004: val_loss did not improve from 0.69315
# 20000/20000 [==============================] - 716s 36ms/sample - loss: 0.6932 - accuracy: 0.5017 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6932 - accuracy: 0.5016
# Epoch 00005: val_loss did not improve from 0.69315
# 20000/20000 [==============================] - 713s 36ms/sample - loss: 0.6932 - accuracy: 0.5018 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6933 - accuracy: 0.4943
# Epoch 00006: val_loss did not improve from 0.69315
# 20000/20000 [==============================] - 713s 36ms/sample - loss: 0.6933 - accuracy: 0.4945 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 7/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6932 - accuracy: 0.5012
# Epoch 00007: val_loss did not improve from 0.69315
# 20000/20000 [==============================] - 713s 36ms/sample - loss: 0.6932 - accuracy: 0.5009 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 8/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6933 - accuracy: 0.4945
# Epoch 00008: val_loss did not improve from 0.69315
# 20000/20000 [==============================] - 718s 36ms/sample - loss: 0.6933 - accuracy: 0.4944 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 9/10
# 19968/20000 [============================>.] - ETA: 1s - loss: 0.6933 - accuracy: 0.5004
# Epoch 00009: val_loss improved from 0.69315 to 0.69315, saving model to ../model/dogsvscats-binary-09-0.6931.hdf5
# 20000/20000 [==============================] - 730s 36ms/sample - loss: 0.6933 - accuracy: 0.5004 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 10/10
# 19968/20000 [============================>.] - ETA: 0s - loss: 0.6932 - accuracy: 0.5007
# Epoch 00010: val_loss did not improve from 0.69315
# 20000/20000 [==============================] - 444s 22ms/sample - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6933 - val_accuracy: 0.5000

# %%
# del model

# %%
# model = keras.models.load_model('../model/dogsvscats-02-0.9341.hdf5')

# %%
# model.evaluate(x_test , y_test, verbose=0)
